# %%
import astropy
from astropy.io import fits
from astropy.table import Table
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from astropy.coordinates import search_around_sky, SkyCoord
from astropy import units as u
import os, sys

# %%
root_folder = "/media/joshua/HDD_fun2/Public/"
filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-207987.fits"

filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-207988.fits"
filepath = "/media/joshua/HDD_fun2/Public/EUC_H/imageEUC_H-207988.fits"
#filepath = "/media/joshua/HDD_fun2/Public/EUC_VIS/imageEUC_VIS-207988.fits"

lens_data = fits.open(filepath)
lens_data.info()
#print("info:", lens_data.info())
img = lens_data[0].data
plt.imshow(img)
plt.colorbar()
plt.show()
# Out:
# Filename: /media/joshua/HDD_fun2/Public/EUC_H/imageEUC_H-207988.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   (66, 66)   float32

# %%
filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-207987.fits"

#filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-207988.fits"
#filepath = "/media/joshua/HDD_fun2/Public/EUC_H/imageEUC_H-207988.fits"
#filepath = "/media/joshua/HDD_fun2/Public/EUC_VIS/imageEUC_VIS-207988.fits"

lens_data = fits.open(filepath)
lens_data.info()
#print("info:", lens_data.info())
img = lens_data[0].data
plt.imshow(img)
plt.colorbar()
plt.show()
# Out:
# Filename: /media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-207987.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   (66, 66)   float32

# %%
#train_data = pd.read_csv(root_folder + "image_catalog2.0train_v2.csv" , skiprows=27)
train_data = pd.read_csv(root_folder + "image_catalog2.0train_v2.csv", header = 0)

# %%
train_data.head()
# Out:
#    Unnamed: 0      ID        x_crit        y_crit  source_ID  z_source  \
# 0        4719  200001  3.467590e-07  1.388970e-07       5131      1.96
# 1        5721  200002  2.440650e-07 -2.128040e-07       7183      1.96
# 2        3090  200003  4.086340e-07  2.556650e-07       4746      2.10
# 3        4786  200004  7.584890e-08 -1.600640e-08       4426      1.93
# 4        2874  200005  2.980050e-07  3.114750e-07       3389      2.62
#
#      z_lens  mag_source      ein_area  n_crit  ...  mag_eff    sb_contrast  \
# 0  0.699792     22.0469  3.714770e-10      19  ...  2.35301   5.416460e-01
# 1  0.522781     25.4845  5.677310e-10      12  ...  3.62894   1.375200e+00
# 2  0.684567     25.4078  1.857780e-09      41  ...      NaN -1.000000e+130
# 3  0.540055     25.6997  7.307720e-10      24  ...  3.03859   3.571940e-01
# 4  0.734329     26.0315  6.982860e-10      23  ...  1.62523   8.474200e-01
#
#    color_diff  n_gal_3  n_gal_5  n_gal_10     halo_mass     star_mass  \
# ...

# %%
train_data[train_data['ID'] == 226305]
# Out:
#        Unnamed: 0      ID        x_crit        y_crit  source_ID  z_source  \
# 26304       10000  226305 -2.665080e-07  3.503120e-07       3059      2.47
#
#         z_lens  mag_source      ein_area  n_crit  ...  mag_eff  sb_contrast  \
# 26304  0.59807     27.5047  3.348540e-10      20  ...  7.28024     0.166005
#
#        color_diff  n_gal_3  n_gal_5  n_gal_10     halo_mass     star_mass  \
# 26304      1.2779        0        0         4  2.335180e+13  3.370170e+11
#
#        mag_lens  n_sources
# 26304   20.2912          1
#
# [1 rows x 27 columns]

# %%
filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-226305.fits"

#filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-226305.fits"
#filepath = "/media/joshua/HDD_fun2/Public/EUC_H/imageEUC_H-207988.fits"
#filepath = "/media/joshua/HDD_fun2/Public/EUC_VIS/imageEUC_VIS-226305.fits"

lens_data = fits.open(filepath)
lens_data.info()
#print("info:", lens_data.info())
img = lens_data[0].data
plt.imshow(img)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-8f28a36d2dcf> in <module>
#       5 #filepath = "/media/joshua/HDD_fun2/Public/EUC_VIS/imageEUC_VIS-226305.fits"
#       6
# ----> 7 lens_data = fits.open(filepath)
#       8 lens_data.info()
#       9 #print("info:", lens_data.info())
#
# ~/miniconda3/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     149
#     150     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 151                             lazy_load_hdus, **kwargs)
#     152
#     153
#
# ~/miniconda3/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     388         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
# ...
