# %%
import astropy
from astropy.io import fits
from astropy.table import Table
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from astropy.coordinates import search_around_sky, SkyCoord
from astropy import units as u
import os, sys

# %%
root_folder = "/media/joshua/HDD_fun2/Public/"
filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-207987.fits"

filepath = "/media/joshua/HDD_fun2/Public/EUC_Y/imageEUC_Y-207988.fits"
filepath = "/media/joshua/HDD_fun2/Public/EUC_J/imageEUC_J-207988.fits"

lens_data = fits.open(filepath)
lens_data.info()
#print("info:", lens_data.info())
img = lens_data[0].data
plt.imshow(img)
plt.show()
# Out:
# Filename: /media/joshua/HDD_fun2/Public/EUC_J/imageEUC_J-207988.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   (66, 66)   float32

# %%
train_data = pd.read_csv(root_folder + "image_catalog2.0train.csv" , skiprows=28)

# %%
train_data.head(100)
# Out:
#     Unnamed: 0      ID        x_crit        y_crit  source_ID  z_source  \
# 0         4719  200001  3.467590e-07  1.388970e-07       5131      1.96
# 1         5721  200002  2.440650e-07 -2.128040e-07       7183      1.96
# 2         3090  200003  4.086340e-07  2.556650e-07       4746      2.10
# 3         4786  200004  7.584890e-08 -1.600640e-08       4426      1.93
# 4         2874  200005  2.980050e-07  3.114750e-07       3389      2.62
# ..         ...     ...           ...           ...        ...       ...
# 95        3541  200096 -2.150270e-07  2.710690e-07       5427      1.75
# 96        3427  200097  1.774170e-07  3.241790e-07       1945      1.59
# 97        6469  200098 -2.960800e-08  1.364360e-07       8873      2.26
# 98        8098  200099 -3.036950e-07 -3.568980e-07       8176      2.00
# 99        5150  200100  3.386690e-07  2.602150e-08       9732      2.33
#
#       z_lens  mag_source      ein_area  n_crit  ...  mag_eff    sb_contrast  \
# 0   0.699792     22.0469  3.714770e-10      19  ...  2.35301   5.416460e-01
# 1   0.522781     25.4845  5.677310e-10      12  ...  3.62894   1.375200e+00
# 2   0.684567     25.4078  1.857780e-09      41  ...      NaN -1.000000e+130
# 3   0.540055     25.6997  7.307720e-10      24  ...  3.03859   3.571940e-01
# 4   0.734329     26.0315  6.982860e-10      23  ...  1.62523   8.474200e-01
# ..       ...         ...           ...     ...  ...      ...            ...
# 95  0.389431     26.1179  3.739360e-10      14  ...  2.03595   5.038600e-01
# 96  0.684567     27.0648  1.620410e-09      31  ...  2.86411   9.131900e-02
# 97  0.684567     26.1045  1.752040e-09      36  ...  1.50248   7.853890e-01
# 98  0.894715     25.4877  1.421560e-10      14  ...  2.21466   6.168590e-02
# 99  0.684567     27.6100  1.871970e-09      42  ...      NaN -1.000000e+130
#
#     color_diff  n_gal_3  n_gal_5  n_gal_10     halo_mass     star_mass  \
# 0      1.03438        1        2         5  5.046820e+13  6.426010e+11
# 1      2.04657        0        0         4  1.027460e+14  8.192230e+11
# 2      1.25909        2        2        10  4.105040e+14  1.151740e+12
# 3      1.89433        1        4         9  1.729910e+14  4.497190e+11
# 4      1.32121        1        3         9  7.507740e+13  8.194420e+11
# ..         ...      ...      ...       ...           ...           ...
# 95     1.03390        1        2         4  7.171420e+13  4.505430e+11
# 96     1.28081        1        2         7  4.105040e+14  1.151740e+12
# 97     1.16502        1        2         6  4.105040e+14  1.151740e+12
# 98     2.29186        0        2         4  2.619030e+13  3.357590e+11
# 99     2.14121        2        4         9  4.105040e+14  1.151740e+12
#
#     mag_lens  n_sources
# 0    20.2312          1
# 1    18.9784          1
# 2    19.2772          0
# 3    19.1146          1
# 4    20.3108          1
# ..       ...        ...
# 95   18.6841          1
# 96   19.2821          1
# 97   19.2821          1
# 98   21.6966          1
# 99   19.2885          1
#
# [100 rows x 27 columns]
